# %%
import pandas as pd

# %%
df = pd.read_excel('../data/raw/chatbot_phase2.xlsx', sheet_name='Total')

# %%
df_result = pd.read_excel('../data/processed/response_cleaned2.xlsx', sheet_name='Sheet1', index_col=0)

# %%
df = df.join(df_result['ingredients_final'])

# %%
df
# Out:
#       Entry               date&time                            user_id  \
# 0         1 2024-02-28 10:23:11.000  U63bd4136638ded1f62047653d8415976
# 1         2 2024-02-28 13:27:21.000  Uf45171994bda44f6f96d488254d8a64b
# 2         3 2024-02-28 13:43:47.000  U56e9322eba7a14a50e8905adf37dd90b
# 3         4 2024-02-28 13:52:25.000  Ude380ef1db88614690572403bfcb84cb
# 4         5 2024-02-28 19:08:57.000  U56e9322eba7a14a50e8905adf37dd90b
# ...     ...                     ...                                ...
# 4032   3973 2024-09-29 01:00:42.873  Ud6e41aff1c1098dce9f83ba6bfcd769e
# 4033   3974 2024-09-29 01:02:56.983  Ud6e41aff1c1098dce9f83ba6bfcd769e
# 4034   3975 2024-09-29 14:07:46.879  Ud6e41aff1c1098dce9f83ba6bfcd769e
# 4035   3976 2024-09-29 14:09:04.244  Ud6e41aff1c1098dce9f83ba6bfcd769e
# 4036   3977 2024-09-29 20:04:07.705  Ud6e41aff1c1098dce9f83ba6bfcd769e
#
#                 user_name food_time  \
# 0                🍀🌷🌻Nok🍓🍇      เย็น
# 1     บรรทม เปรม ศรีวิชัย   กลางวัน
# 2             💐🐥~Pairy~⛄💐      เช้า
# 3                    Zoup      เช้า
# 4             💐🐥~Pairy~⛄💐      เย็น
# ...                   ...       ...
# 4032                 Kate   กลางวัน
# 4033                 Kate      เย้น
# 4034                 Kate      เช้า
# 4035                 Kate   กลางวัน
# 4036                 Kate      เย้น
#
#                                               List menu  \
# 0                สปาเก็ตตี้ พิซซ่า ซอสมะเขือเทศ ปลาหมึก
# 1     เส้นหมี่ ลูกชิ้น หมูชิ้น ผักบุ้ง ถั่วงอก น้ำเปล่า
# 2           ข้าวต้ม ไข่เจียว ผักคะน้า ปลาเค็ม ยำไข่เค็ม
# 3                               นําเต้าหู้ ไข่ ข้าวโอ้ต
# 4         ซูชิ ไข่ตุ๋นญี่ปุ่น ไอศรีมช็อคโกแลต น้ำสไปร์ท
# ...                                                 ...
# 4032                 ก๋วยเตี๋ยว ไข่ปลากมึก ไข่ ผักคะน้า
# 4033                                     เต้าฮวย น้ำขิง
# 4034                             ปลา พริกแกง ผักบุ้งผัด
# 4035                                 บะหมี่ หมู ลูกชิ้น
# 4036  หมูแหนม ข้าวทอด เครื่องยำ กะหล่ำ ชะพู ทานยาfis...
#
#       0 แยกอาหารมาแล้ว 1 ยังไม่แยกมา  ynbloating  bloatseverity  ynabdopain  \
# 0                                  1           0              0           0
# 1                                  0           0              0           0
# 2                                  1           0              0           1
# 3                                  0           1              5           0
# 4                                  0           1              4           1
# ...                              ...         ...            ...         ...
# 4032                               1           0              0           0
# 4033                               0           1              2           0
# 4034                               0           0              0           0
# 4035                               0           0              0           0
# 4036                               1           1              2           0
#
#       abdoseverity  satisfy daily  BMtoday  bmtype  \
# 0                0        5     5        0       0
# 1                0        5     0        0       0
# 2                1        4     4        1       4
# 3                0        5     6        0       0
# 4                1        5     3        0       5
# ...            ...      ...   ...      ...     ...
# 4032             0       10     0        1       5
# 4033             1       10     0        1       5
# 4034             0       10     0        2       6
# 4035             0       10     0        2       6
# 4036             0       10     2        2       6
#
#                                       ingredients_final
# 0     ['สปาเก็ตตี้', 'พิซซ่า', 'ซอสมะเขือเทศ', 'ปลาห...
# 1     ['เส้นห', 'ลูกชิ้น', 'หมูชิ้น', 'ผักบุ้ง', 'ถั...
# 2           ['ไข่', 'ผักคะน้า', 'ปลาเค็ม', 'ยำไข่เค็ม']
# 3                     ['นําเต้าหู้', 'ไข่', 'ข้าวโอ้ต']
# 4     ['ซูชิ', 'ไข่ตุ๋นญี่ปุ่น', 'ไอศรีมช็อคโกแลต', ...
# ...                                                 ...
# 4032    ['ก๋วยเตี๋ยว', 'ไข่ปลากมึก', 'ไข่', 'ผักคะน้า']
# 4033                              ['เต้าฮวย', 'น้ำขิง']
# 4034                      ['ปลา', 'พริกแกง', 'ผักบุ้ง']
# 4035                          ['บะห', 'หมู', 'ลูกชิ้น']
# 4036  ['เครื่องยำ', 'กะหล่ำ', 'ชะพู', 'ทานยาfish', '...
#
# [4037 rows x 16 columns]

# %%
datetime_col = 'date&time'

# Define the custom format for parsing the datetime string
datetime_format = '%d-%m-%Y %I:%M:%S %p'

# Convert the column to datetime objects using the specified format
# The errors='coerce' will turn unparseable values into NaT (Not a Time)
df[datetime_col] = pd.to_datetime(df[datetime_col], format=datetime_format, errors='coerce')

# Localize the naive datetime objects to the Bangkok timezone
# df[datetime_col] = df[datetime_col].dt.tz_localize('Asia/Bangkok', ambiguous=False)

# %%
df.dtypes
# Out:
# Entry                                      int64
# date&time                         datetime64[ns]
# user_id                                   object
# user_name                                 object
# food_time                                 object
# List menu                                 object
# 0 แยกอาหารมาแล้ว 1 ยังไม่แยกมา             int64
# ynbloating                                 int64
# bloatseverity                              int64
# ynabdopain                                 int64
# abdoseverity                               int64
# satisfy                                    int64
# daily                                     object
# BMtoday                                    int64
# bmtype                                     int64
# dtype: object

# %%
# def append_previous_meals(df):
#     """
#     Appends the 'List menu' from the two previous entries (T-1 and T-2) 
#     for each user to the current entry (T) in the DataFrame.

#     Args:
#         df (pd.DataFrame): The input DataFrame.

#     Returns:
#         pd.DataFrame: The DataFrame with new columns for the previous meals.
#     """
#     # Ensure 'date&time' is in datetime format and sort the DataFrame
#     df['date&time'] = pd.to_datetime(df['date&time'], )
#     df = df.sort_values(by=['user_id', 'date&time']).reset_index(drop=True)

#     # Initialize new columns
#     df['List menu T-1'] = None
#     df['List menu T-2'] = None

#     # Iterate through each user
#     for user_id in df['user_id'].unique():
#         user_df = df[df['user_id'] == user_id].copy()

#         # Shift the 'List menu' column to get T-1 and T-2 meals
#         user_df['List menu T-1'] = user_df['ingredients_final'].shift(1)
#         user_df['List menu T-2'] = user_df['ingredients_final'].shift(2)

#         # Update the main DataFrame with the shifted values
#         df.loc[user_df.index, 'List menu T-1'] = user_df['List menu T-1']
#         df.loc[user_df.index, 'List menu T-2'] = user_df['List menu T-2']

#     return df

# %%
import numpy as np

def append_previous_meals(df):
    """
    Appends the 'List menu' from the two previous entries (T-1 and T-2) 
    for each user, given that they are within the last 24 hours.

    Args:
        df (pd.DataFrame): The input DataFrame.

    Returns:
        pd.DataFrame: The DataFrame with new columns for the previous meals,
                      with time-based constraints.
    """
    # 1. Ensure 'date&time' is a datetime object and sort by user and time
    df['date&time'] = pd.to_datetime(df['date&time'])
    df = df.sort_values(by=['user_id', 'date&time']).reset_index(drop=True)

    # 2. Shift the 'date&time' and 'List menu' columns
    # We use a groupby operation for per-user shifting
    df['date&time T-1'] = df.groupby('user_id')['date&time'].shift(1)
    df['List menu T-1'] = df.groupby('user_id')['List menu'].shift(1)

    df['date&time T-2'] = df.groupby('user_id')['date&time'].shift(2)
    df['List menu T-2'] = df.groupby('user_id')['List menu'].shift(2)

    # 3. Calculate time differences to apply the 24-hour rule
    time_diff_t1 = df['date&time'] - df['date&time T-1']
    time_diff_t2 = df['date&time'] - df['date&time T-2']

    # 4. Use boolean masks to filter based on the 24-hour constraint
    # pd.Timedelta(days=1) represents a 24-hour duration
    df.loc[time_diff_t1 > pd.Timedelta(days=1), 'List menu T-1'] = np.nan
    df.loc[time_diff_t2 > pd.Timedelta(days=1.5), 'List menu T-2'] = np.nan

    # 5. Clean up the temporary date columns
    df = df.drop(columns=['date&time T-1', 'date&time T-2'])

    return df

# %%
# Create a sample DataFrame for demonstration
# data = {
#     'Entry': [1, 2, 3, 4, 5, 6],
#     'date&time': ['2025-08-01 12:00:00', '2025-08-01 18:00:00', '2025-08-02 08:00:00',
#                     '2025-08-01 13:00:00', '2025-08-01 20:00:00', '2025-08-02 09:00:00'],
#     'user_id': ['user_A', 'user_A', 'user_A', 'user_B', 'user_B', 'user_B'],
#     'user_name': ['A', 'A', 'A', 'B', 'B', 'B'],
#     'food_time': ['lunch', 'dinner', 'breakfast', 'lunch', 'dinner', 'breakfast'],
#     'List menu': ['rice and curry', 'spaghetti', 'oatmeal', 'salad', 'pizza', 'sandwich'],
#     'แยกอาหารมาแล้ว 1 ยังไม่แยกมา': [1, 1, 1, 1, 1, 1],
#     'ynbloating': [0, 1, 0, 0, 1, 0],
#     'bloatseverity': [0, 3, 0, 0, 4, 0],
#     'ynabdopain': [0, 1, 0, 0, 1, 0],
#     'abdoseverity': [0, 2, 0, 0, 5, 0],
#     'satisfy': [5, 3, 4, 5, 2, 4],
#     'daily': ['ok', 'not ok', 'ok', 'ok', 'not ok', 'ok'],
#     'BMtoday': [1, 1, 1, 1, 1, 1],
#     'bmtype': [4, 4, 4, 4, 4, 4]
# }
# df = pd.DataFrame(data)

# Call the function to process the DataFrame
processed_df = append_previous_meals(df)

# Print the resulting DataFrame
processed_df
# Out:
#       Entry               date&time                            user_id  \
# 0      3201 2024-08-20 14:44:09.292  U00a33f8c677a22fcfe4cd1d1f426600b
# 1      3212 2024-08-21 09:06:02.904  U00a33f8c677a22fcfe4cd1d1f426600b
# 2      3217 2024-08-21 12:18:11.024  U00a33f8c677a22fcfe4cd1d1f426600b
# 3      3227 2024-08-21 19:17:04.078  U00a33f8c677a22fcfe4cd1d1f426600b
# 4      3228 2024-08-22 08:15:12.703  U00a33f8c677a22fcfe4cd1d1f426600b
# ...     ...                     ...                                ...
# 4032   3580 2024-09-05 09:14:23.796  Uff35caf0357cd131a143bf44cc012f59
# 4033   3626 2024-09-07 09:36:56.696  Uff35caf0357cd131a143bf44cc012f59
# 4034   3627 2024-09-07 09:40:04.767  Uff35caf0357cd131a143bf44cc012f59
# 4035   3901 2024-09-20 16:30:53.982  Uff35caf0357cd131a143bf44cc012f59
# 4036   3902 2024-09-20 16:34:05.358  Uff35caf0357cd131a143bf44cc012f59
#
#             user_name                                        food_time  \
# 0         น.อ.จุมพจน์                                          กลางวัน
# 1         น.อ.จุมพจน์                                             เช้า
# 2         น.อ.จุมพจน์                                          กลางวัน
# 3         น.อ.จุมพจน์                                             เย็น
# 4         น.อ.จุมพจน์                                             เช้า
# ...               ...                                              ...
# 4032  Sirada Kosumpan                                             เย้น
# 4033  Sirada Kosumpan                                          กลางวัน
# 4034  Sirada Kosumpan                                             เย้น
# 4035  Sirada Kosumpan  กั้ง กุ้ง ทอดกระเทียม\nไข่เจียว\nหอยหวานต้ม\n\n
# 4036  Sirada Kosumpan            ผัดมักกะโรนี\nแตงโม\nกล้วยหอม ครึ่งผล
#
#                                               List menu  \
# 0         มะระ หมู ผักชี เห็นชอบ กะปิ สะตอ ข้าว ผักบุ้ง
# 1                                    กาแฟ. แซนวิช เผือก
# 2               ข้าว หมู.คะน้า  หอมใหญ่  มะเขือเทศ ไข่
# 3     ต้มขมิ้นไก่บ้าน  ไก่บ้าน\nผัดฟักทอง ฟักทอง ไข่...
# 4                                  กาแฟ\nข้าวเหนียว หมู
# ...                                                 ...
# 4032                          โจ๊กไก่\nแก้วมังกร\nกล้วย
# 4033       แกงไข่กระทิ\nปลาทอด\nผักมะเขือ\nมังคุด\nโรตี
# 4034                        แกงไข่กระทิ\nปลาทอด\nมังคุด
# 4035    กั้ง กุ้ง ทอดกระเทียม\nไข่เจียว\nหอยหวานต้ม\n\n
# 4036   ผัดมักกะโรนี (กุ้ง)\nแตงโม\nกล้วยหอม ครึ่งผล\n\n
#
#       0 แยกอาหารมาแล้ว 1 ยังไม่แยกมา  ynbloating  bloatseverity  ynabdopain  \
# 0                                  0           1              4           0
# 1                                  1           1              2           0
# 2                                  0           1              3           0
# 3                                  1           1              4           0
# 4                                  0           1              2           0
# ...                              ...         ...            ...         ...
# 4032                               0           0              0           0
# 4033                               1           1              3           0
# 4034                               1           1              5           0
# 4035                               1           0              0           0
# 4036                               1           1              1           1
#
#       abdoseverity  satisfy daily  BMtoday  bmtype  \
# 0                0        6     5        0       0
# 1                0        8     3        1       4
# 2                0        8     3        0       4
# 3                0        8     4        1       5
# 4                0        8     2        1       5
# ...            ...      ...   ...      ...     ...
# 4032             0        3     2        2       3
# 4033             0        3     3        1       2
# 4034             0        2     5        2       3
# 4035             0        2     2        1       4
# 4036             1        2     4        1       2
#
#                                       ingredients_final  \
# 0                   ['กะปิ', 'สะตอ', 'ข้าว', 'ผักบุ้ง']
# 1                          ['กาแฟ.', 'แซนวิช', 'เผือก']
# 2     ['ข้าว', 'หมู.คะน้า', 'หอมใหญ่', 'มะเขือเทศ', ...
# 3     ['ขมิ้นไก่บ้าน', 'ไก่บ้าน', 'ผัดฟักทอง', 'ฟักท...
# 4                         ['กาแฟ', 'ข้าวเหนียว', 'หมู']
# ...                                                 ...
# 4032                  ['โจ๊กไก่', 'แก้วมังกร', 'กล้วย']
# 4033                    ['ผักมะเขือ', 'มังคุด', 'โรตี']
# 4034                                         ['มังคุด']
# 4035                                                 []
# 4036         ['ผัดมักกะโรนี', 'กุ้ง', 'แตงโม', 'กล้วย']
#
#                                           List menu T-1  \
# 0                                                   NaN
# 1         มะระ หมู ผักชี เห็นชอบ กะปิ สะตอ ข้าว ผักบุ้ง
# 2                                    กาแฟ. แซนวิช เผือก
# 3               ข้าว หมู.คะน้า  หอมใหญ่  มะเขือเทศ ไข่
# 4     ต้มขมิ้นไก่บ้าน  ไก่บ้าน\nผัดฟักทอง ฟักทอง ไข่...
# ...                                                 ...
# 4032             แป้งข้าวหมาก\nมังคุด\nกล้วย\nแก้วมังกร
# 4033                                                NaN
# 4034       แกงไข่กระทิ\nปลาทอด\nผักมะเขือ\nมังคุด\nโรตี
# 4035                                                NaN
# 4036    กั้ง กุ้ง ทอดกระเทียม\nไข่เจียว\nหอยหวานต้ม\n\n
#
#                                           List menu T-2
# 0                                                   NaN
# 1                                                   NaN
# 2         มะระ หมู ผักชี เห็นชอบ กะปิ สะตอ ข้าว ผักบุ้ง
# 3                                    กาแฟ. แซนวิช เผือก
# 4               ข้าว หมู.คะน้า  หอมใหญ่  มะเขือเทศ ไข่
# ...                                                 ...
# 4032  ปลาสำลีทอด\nผักกูดลวก  กระเจี๊ยบเขียว มะเขือ\n...
# 4033                                                NaN
# 4034                                                NaN
# 4035                                                NaN
# 4036                                                NaN
#
# [4037 rows x 18 columns]

# %%
processed_df = processed_df.sort_values(by='Entry')

# %%
processed_df.to_excel('../data/processed/response_shifted_T3.xlsx')
