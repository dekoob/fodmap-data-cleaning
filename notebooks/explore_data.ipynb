# %% [markdown]
# # load data

# %%
import pandas as pd

# %%
df = pd.read_excel('../data/raw/chatbot_phase2.xlsx', sheet_name='Total')

# %%
df_result = pd.read_excel('../data/processed/response_cleaned.xlsx', sheet_name='Sheet1', index_col=0)

# %%
df
# Out:
#       Entry                   date&time                            user_id  \
# 0         1         2024-02-28 10:23:11  U63bd4136638ded1f62047653d8415976
# 1         2         2024-02-28 13:27:21  Uf45171994bda44f6f96d488254d8a64b
# 2         3         2024-02-28 13:43:47  U56e9322eba7a14a50e8905adf37dd90b
# 3         4         2024-02-28 13:52:25  Ude380ef1db88614690572403bfcb84cb
# 4         5         2024-02-28 19:08:57  U56e9322eba7a14a50e8905adf37dd90b
# ...     ...                         ...                                ...
# 4032   3973  2024-09-29 01:00:42.873000  Ud6e41aff1c1098dce9f83ba6bfcd769e
# 4033   3974  2024-09-29 01:02:56.983000  Ud6e41aff1c1098dce9f83ba6bfcd769e
# 4034   3975  2024-09-29 14:07:46.879000  Ud6e41aff1c1098dce9f83ba6bfcd769e
# 4035   3976  2024-09-29 14:09:04.244000  Ud6e41aff1c1098dce9f83ba6bfcd769e
# 4036   3977  2024-09-29 20:04:07.705000  Ud6e41aff1c1098dce9f83ba6bfcd769e
#
#                 user_name food_time  \
# 0                🍀🌷🌻Nok🍓🍇      เย็น
# 1     บรรทม เปรม ศรีวิชัย   กลางวัน
# 2             💐🐥~Pairy~⛄💐      เช้า
# 3                    Zoup      เช้า
# 4             💐🐥~Pairy~⛄💐      เย็น
# ...                   ...       ...
# 4032                 Kate   กลางวัน
# 4033                 Kate      เย้น
# 4034                 Kate      เช้า
# 4035                 Kate   กลางวัน
# 4036                 Kate      เย้น
#
#                                               List menu  \
# 0                สปาเก็ตตี้ พิซซ่า ซอสมะเขือเทศ ปลาหมึก
# 1     เส้นหมี่ ลูกชิ้น หมูชิ้น ผักบุ้ง ถั่วงอก น้ำเปล่า
# 2           ข้าวต้ม ไข่เจียว ผักคะน้า ปลาเค็ม ยำไข่เค็ม
# 3                               นําเต้าหู้ ไข่ ข้าวโอ้ต
# 4         ซูชิ ไข่ตุ๋นญี่ปุ่น ไอศรีมช็อคโกแลต น้ำสไปร์ท
# ...                                                 ...
# 4032                 ก๋วยเตี๋ยว ไข่ปลากมึก ไข่ ผักคะน้า
# 4033                                     เต้าฮวย น้ำขิง
# 4034                             ปลา พริกแกง ผักบุ้งผัด
# 4035                                 บะหมี่ หมู ลูกชิ้น
# 4036  หมูแหนม ข้าวทอด เครื่องยำ กะหล่ำ ชะพู ทานยาfis...
#
#       0 แยกอาหารมาแล้ว 1 ยังไม่แยกมา  ynbloating  bloatseverity  ynabdopain  \
# 0                                  1           0              0           0
# 1                                  0           0              0           0
# 2                                  1           0              0           1
# 3                                  0           1              5           0
# 4                                  0           1              4           1
# ...                              ...         ...            ...         ...
# 4032                               1           0              0           0
# 4033                               0           1              2           0
# 4034                               0           0              0           0
# 4035                               0           0              0           0
# 4036                               1           1              2           0
#
#       abdoseverity  satisfy daily  BMtoday  bmtype
# 0                0        5     5        0       0
# 1                0        5     0        0       0
# 2                1        4     4        1       4
# 3                0        5     6        0       0
# 4                1        5     3        0       5
# ...            ...      ...   ...      ...     ...
# 4032             0       10     0        1       5
# 4033             1       10     0        1       5
# 4034             0       10     0        2       6
# 4035             0       10     0        2       6
# 4036             0       10     2        2       6
#
# [4037 rows x 15 columns]

# %%
df_result.columns
# Out:
# Index(['original', 'cleaned_text', 'ingredients_raw', 'ingredients_final',
#        'ingredient_count', 'row_id'],
#       dtype='object')

# %%
df_result.drop(['row_id'], inplace=True, axis=1)

# %%
df_result
# Out:
#                                                original  \
# 0                สปาเก็ตตี้ พิซซ่า ซอสมะเขือเทศ ปลาหมึก
# 1     เส้นหมี่ ลูกชิ้น หมูชิ้น ผักบุ้ง ถั่วงอก น้ำเปล่า
# 2           ข้าวต้ม ไข่เจียว ผักคะน้า ปลาเค็ม ยำไข่เค็ม
# 3                               นําเต้าหู้ ไข่ ข้าวโอ้ต
# 4         ซูชิ ไข่ตุ๋นญี่ปุ่น ไอศรีมช็อคโกแลต น้ำสไปร์ท
# ...                                                 ...
# 4032                 ก๋วยเตี๋ยว ไข่ปลากมึก ไข่ ผักคะน้า
# 4033                                     เต้าฮวย น้ำขิง
# 4034                             ปลา พริกแกง ผักบุ้งผัด
# 4035                                 บะหมี่ หมู ลูกชิ้น
# 4036  หมูแหนม ข้าวทอด เครื่องยำ กะหล่ำ ชะพู ทานยาfis...
#
#                                            cleaned_text  \
# 0                สปาเก็ตตี้ พิซซ่า ซอสมะเขือเทศ ปลาหมึก
# 1     เส้นหมี่ ลูกชิ้น หมูชิ้น ผักบุ้ง ถั่วงอก น้ำเปล่า
# 2                   ไข่เจียว ผักคะน้า ปลาเค็ม ยำไข่เค็ม
# 3                               นําเต้าหู้ ไข่ ข้าวโอ้ต
# 4         ซูชิ ไข่ตุ๋นญี่ปุ่น ไอศรีมช็อคโกแลต น้ำสไปร์ท
# ...                                                 ...
# 4032                 ก๋วยเตี๋ยว ไข่ปลากมึก ไข่ ผักคะน้า
# 4033                                     เต้าฮวย น้ำขิง
# 4034                                ปลา พริกแกง ผักบุ้ง
# 4035                                 บะหมี่ หมู ลูกชิ้น
# 4036                เครื่องยำ กะหล่ำ ชะพู ทานยาfish oil
#
#                                         ingredients_raw  \
# 0     ['สปาเก็ตตี้', 'พิซซ่า', 'ซอสมะเขือเทศ', 'ปลาห...
# 1     ['เส้นหมี่', 'ลูกชิ้น', 'หมูชิ้น', 'ผักบุ้ง', ...
# 2      ['ไข่เจียว', 'ผักคะน้า', 'ปลาเค็ม', 'ยำไข่เค็ม']
# 3                     ['นําเต้าหู้', 'ไข่', 'ข้าวโอ้ต']
# 4     ['ซูชิ', 'ไข่ตุ๋นญี่ปุ่น', 'ไอศรีมช็อคโกแลต', ...
# ...                                                 ...
# 4032    ['ก๋วยเตี๋ยว', 'ไข่ปลากมึก', 'ไข่', 'ผักคะน้า']
# 4033                              ['เต้าฮวย', 'น้ำขิง']
# 4034                      ['ปลา', 'พริกแกง', 'ผักบุ้ง']
# 4035                       ['บะหมี่', 'หมู', 'ลูกชิ้น']
# 4036  ['เครื่องยำ', 'กะหล่ำ', 'ชะพู', 'ทานยาfish', '...
#
#                                       ingredients_final  ingredient_count
# 0     ['สปาเก็ตตี้', 'พิซซ่า', 'ซอสมะเขือเทศ', 'ปลาห...                 4
# 1     ['หมี่', 'ลูกชิ้น', 'หมูชิ้น', 'ผักบุ้ง', 'ถั่...                 6
# 2      ['ไข่เจียว', 'ผักคะน้า', 'ปลาเค็ม', 'ยำไข่เค็ม']                 4
# 3                     ['นําเต้าหู้', 'ไข่', 'ข้าวโอ้ต']                 3
# 4     ['ซูชิ', 'ไข่ตุ๋นญี่ปุ่น', 'ไอศรีมช็อคโกแลต', ...                 4
# ...                                                 ...               ...
# 4032    ['ก๋วยเตี๋ยว', 'ไข่ปลากมึก', 'ไข่', 'ผักคะน้า']                 4
# 4033                              ['เต้าฮวย', 'น้ำขิง']                 2
# 4034                      ['ปลา', 'พริกแกง', 'ผักบุ้ง']                 3
# 4035                       ['บะหมี่', 'หมู', 'ลูกชิ้น']                 3
# 4036  ['เครื่องยำ', 'กะหล่ำ', 'ชะพู', 'ทานยาfish', '...                 5
#
# [4037 rows x 5 columns]

# %%
joined_df = df.join(df_result)

# %%
joined_df.drop(['List menu'], inplace=True, axis=1)

# %%
joined_df.head()
# Out:
#    Entry            date&time                            user_id  \
# 0      1  2024-02-28 10:23:11  U63bd4136638ded1f62047653d8415976
# 1      2  2024-02-28 13:27:21  Uf45171994bda44f6f96d488254d8a64b
# 2      3  2024-02-28 13:43:47  U56e9322eba7a14a50e8905adf37dd90b
# 3      4  2024-02-28 13:52:25  Ude380ef1db88614690572403bfcb84cb
# 4      5  2024-02-28 19:08:57  U56e9322eba7a14a50e8905adf37dd90b
#
#              user_name food_time  0 แยกอาหารมาแล้ว 1 ยังไม่แยกมา  ynbloating  \
# 0             🍀🌷🌻Nok🍓🍇      เย็น                               1           0
# 1  บรรทม เปรม ศรีวิชัย   กลางวัน                               0           0
# 2          💐🐥~Pairy~⛄💐      เช้า                               1           0
# 3                 Zoup      เช้า                               0           1
# 4          💐🐥~Pairy~⛄💐      เย็น                               0           1
#
#    bloatseverity  ynabdopain  abdoseverity  satisfy daily  BMtoday  bmtype  \
# 0              0           0             0        5     5        0       0
# 1              0           0             0        5     0        0       0
# 2              0           1             1        4     4        1       4
# 3              5           0             0        5     6        0       0
# 4              4           1             1        5     3        0       5
#
#                                             original  \
# 0             สปาเก็ตตี้ พิซซ่า ซอสมะเขือเทศ ปลาหมึก
# 1  เส้นหมี่ ลูกชิ้น หมูชิ้น ผักบุ้ง ถั่วงอก น้ำเปล่า
# 2        ข้าวต้ม ไข่เจียว ผักคะน้า ปลาเค็ม ยำไข่เค็ม
# 3                            นําเต้าหู้ ไข่ ข้าวโอ้ต
# 4      ซูชิ ไข่ตุ๋นญี่ปุ่น ไอศรีมช็อคโกแลต น้ำสไปร์ท
#
#                                         cleaned_text  \
# 0             สปาเก็ตตี้ พิซซ่า ซอสมะเขือเทศ ปลาหมึก
# 1  เส้นหมี่ ลูกชิ้น หมูชิ้น ผักบุ้ง ถั่วงอก น้ำเปล่า
# 2                ไข่เจียว ผักคะน้า ปลาเค็ม ยำไข่เค็ม
# 3                            นําเต้าหู้ ไข่ ข้าวโอ้ต
# 4      ซูชิ ไข่ตุ๋นญี่ปุ่น ไอศรีมช็อคโกแลต น้ำสไปร์ท
#
#                                      ingredients_raw  \
# 0  ['สปาเก็ตตี้', 'พิซซ่า', 'ซอสมะเขือเทศ', 'ปลาห...
# 1  ['เส้นหมี่', 'ลูกชิ้น', 'หมูชิ้น', 'ผักบุ้ง', ...
# 2   ['ไข่เจียว', 'ผักคะน้า', 'ปลาเค็ม', 'ยำไข่เค็ม']
# 3                  ['นําเต้าหู้', 'ไข่', 'ข้าวโอ้ต']
# 4  ['ซูชิ', 'ไข่ตุ๋นญี่ปุ่น', 'ไอศรีมช็อคโกแลต', ...
#
#                                    ingredients_final  ingredient_count
# 0  ['สปาเก็ตตี้', 'พิซซ่า', 'ซอสมะเขือเทศ', 'ปลาห...                 4
# 1  ['หมี่', 'ลูกชิ้น', 'หมูชิ้น', 'ผักบุ้ง', 'ถั่...                 6
# 2   ['ไข่เจียว', 'ผักคะน้า', 'ปลาเค็ม', 'ยำไข่เค็ม']                 4
# 3                  ['นําเต้าหู้', 'ไข่', 'ข้าวโอ้ต']                 3
# 4  ['ซูชิ', 'ไข่ตุ๋นญี่ปุ่น', 'ไอศรีมช็อคโกแลต', ...                 4

# %% [markdown]
# # Generate Freq itemset

# %%
joined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4037 entries, 0 to 4036
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Entry                           4037 non-null   int64
#  1   date&time                       4037 non-null   object
#  2   user_id                         4037 non-null   object
#  3   user_name                       4037 non-null   object
#  4   food_time                       4037 non-null   object
#  5   0 แยกอาหารมาแล้ว 1 ยังไม่แยกมา  4037 non-null   int64
#  6   ynbloating                      4037 non-null   int64
#  7   bloatseverity                   4037 non-null   int64
#  8   ynabdopain                      4037 non-null   int64
#  9   abdoseverity                    4037 non-null   int64
#  10  satisfy                         4037 non-null   int64
#  11  daily                           4037 non-null   object
#  12  BMtoday                         4037 non-null   int64
#  13  bmtype                          4037 non-null   int64
#  14  original                        4037 non-null   object
#  15  cleaned_text                    3827 non-null   object
#  16  ingredients_raw                 4037 non-null   object
#  17  ingredients_final               4037 non-null   object
#  18  ingredient_count                4037 non-null   int64
# dtypes: int64(10), object(9)
# memory usage: 599.4+ KB

# %% [markdown]
# For simplicity, start off with possibility of bloating at meal 'T'

# %%
df_filtered = joined_df[joined_df['ynbloating']==1]

# %%
import ast

ingre_df = df_filtered['ingredients_final'].apply(ast.literal_eval)

# %%
ingre_df
# Out:
# 3                             [นําเต้าหู้, ไข่, ข้าวโอ้ต]
# 4       [ซูชิ, ไข่ตุ๋นญี่ปุ่น, ไอศรีมช็อคโกแลต, น้ำสไป...
# 5       [ข้าว, ไก่, กระเทียม, พริกไทย, หมี่แดง, ถั่วงอ...
# 7                                                      []
# 9       [ถั่วลิสง, ผักกาดแก้ว, เสาว, ผล, สัปปะรด, ใหญ่...
#                               ...
# 4023       [ผักสลัด, ทูน่า, แครอท, แตงกวา, น้ำสลัดซีฟู้ด]
# 4026                            [มันปลา, เบคอน, เนื้อไก่]
# 4027                                               [เช้า]
# 4033                                    [เต้าฮวย, น้ำขิง]
# 4036            [เครื่องยำ, กะหล่ำ, ชะพู, ทานยาfish, oil]
# Name: ingredients_final, Length: 2010, dtype: object

# %%
from mlxtend.preprocessing import TransactionEncoder

dataset = ingre_df
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df_exploded = pd.DataFrame(te_ary, columns=te.columns_)
df_exploded
# Out:
#       (กระหล่ำปลี  (กระเจี๊ยบเขียว  (กะหล่ำปลี  (กุ้ง)  (ขิงซอย  (ข้าวขาว)  \
# 0           False            False       False   False    False      False
# 1           False            False       False   False    False      False
# 2           False            False       False   False    False      False
# 3           False            False       False   False    False      False
# 4           False            False       False   False    False      False
# ...           ...              ...         ...     ...      ...        ...
# 2005        False            False       False   False    False      False
# 2006        False            False       False   False    False      False
# 2007        False            False       False   False    False      False
# 2008        False            False       False   False    False      False
# 2009        False            False       False   False    False      False
#
#       (จิงจูฉ่าย  (บรอคโคลี่   (บวบ  (ผักบุ้ง  ...  ไอศรีมช็อคโกแลต  \
# 0          False       False  False     False  ...            False
# 1          False       False  False     False  ...             True
# 2          False       False  False     False  ...            False
# 3          False       False  False     False  ...            False
# 4          False       False  False     False  ...            False
# ...          ...         ...    ...       ...  ...              ...
# 2005       False       False  False     False  ...            False
# 2006       False       False  False     False  ...            False
# 2007       False       False  False     False  ...            False
# 2008       False       False  False     False  ...            False
# 2009       False       False  False     False  ...            False
#
#       ไอศรีมวนิลา  ไอสครีมมอคค่าฟัดส์  ไอสครีมมอคค่าอัลมอนด์ฟัลด์  \
# 0           False               False                       False
# 1           False               False                       False
# 2           False               False                       False
# 3           False               False                       False
# 4           False               False                       False
# ...           ...                 ...                         ...
# 2005        False               False                       False
# 2006        False               False                       False
# 2007        False               False                       False
# 2008        False               False                       False
# 2009        False               False                       False
#
#       ไอสครีมมะม่วงน้ำดอกไม้  ​น้ำเปล่า  “บันทึก”  “บันทึก”มื้อ  \
# 0                      False      False     False         False
# 1                      False      False     False         False
# 2                      False      False     False         False
# 3                      False      False     False         False
# 4                      False      False     False         False
# ...                      ...        ...       ...           ...
# 2005                   False      False     False         False
# 2006                   False      False     False         False
# 2007                   False      False     False         False
# 2008                   False      False     False         False
# 2009                   False      False     False         False
#
#       “บันทึก”มื้อ“  ”บันทึก“
# 0             False     False
# 1             False     False
# 2             False     False
# 3             False     False
# 4             False     False
# ...             ...       ...
# 2005          False     False
# 2006          False     False
# 2007          False     False
# 2008          False     False
# 2009          False     False
#
# [2010 rows x 2346 columns]

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df_exploded, min_support=0.01, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets.sort_values(by='support', ascending=False)
# Out:
#       support                                           itemsets  length
# 12   0.213930                                             (ข้าว)       1
# 49   0.152239                                              (หมู)       1
# 69   0.102488                                              (ไข่)       1
# 97   0.077612                                        (ข้าว, หมู)       2
# 35   0.062189                                             (พริก)       1
# ..        ...                                                ...     ...
# 108  0.010448                                        (ปลา, พริก)       2
# 116  0.010448       (ใบมะกรูด+ตะไคร้+ข่าในรูปบด, สาหร่ายวากาเมะ)       2
# 123  0.010448                                         (ไก่, ไข่)       2
# 125  0.010448    (กระเจี๊ยบเขียว, สาหร่ายวากาเมะ, เครื่องเคียง:)       3
# 132  0.010448  (ใบมะกรูด+ตะไคร้+ข่าในรูปบด, สาหร่ายวากาเมะ, เ...       3
#
# [133 rows x 3 columns]

# %%
from mlxtend.frequent_patterns import association_rules

association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
# Out:
#                                     antecedents  \
# 0                                    ((แป้งบุก)
# 1                                (ผงเห็ดหอม3%))
# 2                                    ((แป้งบุก)
# 3                                     (แป้งมัน)
# 4                              (กระเจี๊ยบเขียว)
# ..                                          ...
# 63  (ใบมะกรูด+ตะไคร้+ข่าในรูปบด, เครื่องเคียง:)
# 64              (สาหร่ายวากาเมะ, เครื่องเคียง:)
# 65                 (ใบมะกรูด+ตะไคร้+ข่าในรูปบด)
# 66                             (สาหร่ายวากาเมะ)
# 67                              (เครื่องเคียง:)
#
#                                      consequents  antecedent support  \
# 0                                 (ผงเห็ดหอม3%))            0.011443
# 1                                     ((แป้งบุก)            0.011443
# 2                                      (แป้งมัน)            0.011443
# 3                                     ((แป้งบุก)            0.011940
# 4                               (สาหร่ายวากาเมะ)            0.014428
# ..                                           ...                 ...
# 63                              (สาหร่ายวากาเมะ)            0.012935
# 64                  (ใบมะกรูด+ตะไคร้+ข่าในรูปบด)            0.011443
# 65               (สาหร่ายวากาเมะ, เครื่องเคียง:)            0.012935
# 66   (ใบมะกรูด+ตะไคร้+ข่าในรูปบด, เครื่องเคียง:)            0.013433
# 67  (ใบมะกรูด+ตะไคร้+ข่าในรูปบด, สาหร่ายวากาเมะ)            0.013930
#
#     consequent support   support  confidence       lift  representativity  \
# 0             0.011443  0.011443    1.000000  87.391304               1.0
# 1             0.011443  0.011443    1.000000  87.391304               1.0
# 2             0.011940  0.011443    1.000000  83.750000               1.0
# 3             0.011443  0.011443    0.958333  83.750000               1.0
# 4             0.013433  0.010945    0.758621  56.475096               1.0
# ..                 ...       ...         ...        ...               ...
# 63            0.013433  0.010448    0.807692  60.128205               1.0
# 64            0.012935  0.010448    0.913043  70.585284               1.0
# 65            0.011443  0.010448    0.807692  70.585284               1.0
# 66            0.012935  0.010448    0.777778  60.128205               1.0
# 67            0.010448  0.010448    0.750000  71.785714               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.011312         inf       1.000000  1.000000   1.000000    1.000000
# 1   0.011312         inf       1.000000  1.000000   1.000000    1.000000
# 2   0.011306         inf       0.999497  0.958333   1.000000    0.979167
# 3   0.011306   23.725373       1.000000  0.958333   0.957851    0.979167
# 4   0.010751    4.087207       0.996673  0.647059   0.755334    0.786718
# ..       ...         ...            ...       ...        ...         ...
# 63  0.010274    5.130149       0.996256  0.656250   0.805074    0.792735
# 64  0.010300   11.351244       0.997244  0.750000   0.911904    0.860368
# 65  0.010300    5.140498       0.998752  0.750000   0.805466    0.860368
# 66  0.010274    4.441791       0.996758  0.656250   0.774866    0.792735
# 67  0.010302    3.958209       1.000000  0.750000   0.747360    0.875000
#
# [68 rows x 14 columns]
